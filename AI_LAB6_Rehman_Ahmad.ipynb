# %%
robots= ["ALpha" , "Beta" , "Gamma"]

print("Robot List : ", robots)
print("First Robot : " ,robots[0])
print("Second Robot : " ,robots[1])
print("Last Robot : " ,robots[-1])
# Out:
# Robot List :  ['ALpha', 'Beta', 'Gamma']
# First Robot :  ALpha
# Second Robot :  Beta
# Last Robot :  Gamma

# %%
robots.append("Delta")
robots.remove("Beta")
print("Update Robots List : ", robots)
# Out:
# Update Robots List :  ['ALpha', 'Gamma', 'Delta']

# %% [markdown]
# ## Try It Yourself
#
# 1. Create a list named fruits with 5 fruit names.
# 2. Print the first and last fruit.
# 3. Add a new fruit and remove one old fruit

# %%
fruits = ["Apple" , "Banana" , "Mango" , "Orange" , "Grapes"]
print("First fruit : " , fruits[0])
print("Last fruit : " , fruits[-1])

fruits.append("Barry")
fruits.remove("Apple")
print("\nUpdate Fruits List : ", fruits)
# Out:
# First fruit :  Apple
# Last fruit :  Grapes
#
# Update Fruits List :  ['Banana', 'Mango', 'Orange', 'Grapes', 'Barry']

# %%
robots={
    "name" :"Alpha",
    "battery":80,
    "status":"Active"
}

print("Robot Name : ",robots["name"])
print("Battery Level : ",robots["battery"])
print("Status:" , robots["status"])
# Out:
# Robot Name :  Alpha
# Battery Level :  80
# Status: Active

# %%
robots["battery"]  = 95
robots["task"] = "Line Following"
print("Update Robot Info : " , robots)
# Out:
# Update Robot Info :  {'name': 'Alpha', 'battery': 95, 'status': 'Active', 'task': 'Line Following'}

# %% [markdown]
# ## ✅ Try It Yourself
#
# - Create a dictionary for a student with keys: name , roll_no , and score .
# - Increase score by 5 and add a new key grade .

# %%
student={
    "name":"Rahman Ahmad",
    "roll_no":"2024-csr-019",
    "score" :90
}

print("Student Dictionary : ", student)

student["score"] += 5
student["grade"] = "A"

print("\n Update Student Dictionary : ", student)
# Out:
# Student Dictionary :  {'name': 'Rahman Ahmad', 'roll_no': '2024-csr-019', 'score': 90}
#
#  Update Student Dictionary :  {'name': 'Rahman Ahmad', 'roll_no': '2024-csr-019', 'score': 95, 'grade': 'A'}

# %%
robots= ["ALpha" ,  "Gamma" , "Delta"]
for r in robots:
    print("Activating Robot : ", r)
# Out:
# Activating Robot :  ALpha
# Activating Robot :  Gamma
# Activating Robot :  Delta

# %%
battery = 5
while battery > 0:
    print("Battery remaining : " , battery)
    battery -=1
# Out:
# Battery remaining :  5
# Battery remaining :  4
# Battery remaining :  3
# Battery remaining :  2
# Battery remaining :  1

# %% [markdown]
# ## ✅ Try It Yourself
# 1. Using a for loop, print each character of the string "ROBOT" .
# 2. Using a while loop, count down from 3 to 1 and then print "Go!" .

# %%
str = "ROBOT"
print("Print  each character of the string 'ROBOT' using for loop :")
for c in str:
    print(c)
# Out:
# Print  each character of the string 'ROBOT' using for loop :
# R
# O
# B
# O
# T

# %%
num = 3
while num >= 1:
    print(num)
    num -=1

print("Go!")
# Out:
# 3
# 2
# 1
# Go!

# %%
battery = 40

if battery > 60:
    print("Battery is Full - Ready for Mission!")
elif battery > 30:
    print("Battery is Medium - Prepare for Recharge.")
else:
    print("Battery Low - Returning to Base.")
# Out:
# Battery is Medium - Prepare for Recharge.

# %% [markdown]
# ## ✅ Try It Yourself
#
# - Take a variable temp = 38 .
# - If temp > 40 print "Alert: High Temperature!", else print "Normal"

# %%
temp = 38
if temp > 40:
    print("Alert: High Temperature!")
else:
    print("Normal")
# Out:
# Normal

# %% [markdown]
# ## 🧩 Mini AI Project: Robot Battery Checker
# - You have 3 robots. Each robot has a battery level.
# - Use a for loop + if condition to print whether each robot can continue working or needs charging

# %%
robots={"Alpha": 75 , "Beta" : 20 , "Gamma": 60 }
for name , battery in robots.items():
    if battery > 50:
        print(name , " -> Battery OK (", battery ,"%)")
    else:
        print(name , " -> Low Battery (" , battery , "%)")
# Out:
# Alpha  -> Battery OK ( 75 %)
# Beta  -> Low Battery ( 20 %)
# Gamma  -> Battery OK ( 60 %)

# %% [markdown]
# ## 🧪 Homework Challenge
# Write a program that:
# 1. Takes 5 temperature readings in a list.
# 2. Prints each temperature using a for loop.
# 3. If any reading is above 40°C, print “Alert: High Temperature!”

# %%
temperatures = [20 , 30 ,40 ,50 ,60]
for t in temperatures:
    print("Temperture :" , t)
    if t > 40 :
        print("Alert: High Temperature!")
# Out:
# Temperture : 20
# Temperture : 30
# Temperture : 40
# Temperture : 50
# Alert: High Temperature!
# Temperture : 60
# Alert: High Temperature!
